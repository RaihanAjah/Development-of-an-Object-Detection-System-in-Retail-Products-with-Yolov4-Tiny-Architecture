# %%
file_test_txt = open('data/test.txt', 'r')


import os
import shutil
import glob

dir_path = "data/obj/"
images = glob.glob(dir_path + '*.jng')

# folders = list(set([image.split('.')[0] for image in images]))
# for folder in folders:
#     if not os.path.exists(dir_path + '/' + folder):
#         os.makedirs(dir_path + '/' + folder)
# for image in images:
#     shutil.move(image, dir_path + '/' + image.split('.')[0] + '/' + image)

# %%
# print(file_test.read())
for f in images:
    print(f)

# %%
import os
import os.path
from PIL import Image
from PIL import ImageFilter

file_test_txt = open('data/test.txt', 'r')
count = 0

f = r'C:\Users\PREDATOR\Documents\Tugas Akhir\Program\obj'
for file in os.listdir(f):
    if (file.endswith(".jpg")):
        
        filenama = "data/obj/" + file

        count += 1
#         print(filenama)

        if file_test_txt.read() == file:
            print(file)
        
        
print(count)
# Out:
# data/obj/0045800719-1929-q6clo7_108_display_2_1.jpg
# data/obj/0046800719-39907-q6ce5u_114_display_1_2.jpg
# data/obj/0046800719-39907-q6ce5u_114_display_1_2_1.jpg
# data/obj/00527EBE-2B4B-45EC-A486-00E061F8A9DB_1_105_c.jpg
# data/obj/0065-80-1119-39917-q6cg9w_111_display_1_1.jpg
# data/obj/0065-80-1119-39917-q6cg9w_111_display_1_1_1.jpg
# data/obj/0070-80-0120-55480-q6cehm_108_display_2_1.jpg
# data/obj/0071-80-0120-7093-q6ciyn_114_display_2_1.jpg
# data/obj/0076E457-9071-4302-BA71-C7714920AB04_1_105_c.jpg
# data/obj/014860FA-5BD5-44CE-A1B0-23FA445EC847_1_105_c.jpg
# data/obj/0153F4FE-9D2C-44D0-9810-3143996FF459_1_105_c.jpg
# data/obj/01639B37-C541-447E-8ACE-ADCA91DCA2CD_1_105_c.jpg
# data/obj/017BFF6D-5EFA-44DC-9446-350AF9352670_1_105_c.jpg
# data/obj/0196115B-7255-45D2-90F6-C39AFCD78EDE_1_105_c.jpg
# data/obj/01DF2BC4-D359-44F4-8993-314492A6E2FE - Futriana Dwi.jpg
# data/obj/0218D90D-79C7-4770-A250-CA7F48B0EC94_1_105_c.jpg
# data/obj/022200002199-56929-q6ctf9_114_display_2_1.jpg
# ...

# %%
print(file_test_txt.read())

# %%
file_test_txt = open('data/test.txt', 'r')
print(file_test_txt.read())
# Out:
# data/obj/0065-80-1119-39917-q6cg9w_111_display_1_1.jpg
# data/obj/014860FA-5BD5-44CE-A1B0-23FA445EC847_1_105_c.jpg
# data/obj/01DF2BC4-D359-44F4-8993-314492A6E2FE - Futriana Dwi.jpg
# data/obj/02220000256-1833-q6c89h_114_display_1_1.jpg
# data/obj/0222002297-36954-q6cp7r_114_display_1_2.jpg
# data/obj/023B9E57-FB7A-43C2-9364-7B9971774BD0_1_105_c.jpg
# data/obj/034A17BE-2CD9-4F04-A9BF-FAED2DC663BD_1_105_c.jpg
# data/obj/0445EA1A-4881-48E6-A186-B53E482FA761_1_105_c.jpg
# data/obj/04943877-EA31-45CC-971F-C9449F782421_1_105_c.jpg
# data/obj/056E939F-9136-4AB7-9042-20231BEC0F6A_1_105_c.jpg
# data/obj/06C798C1-A17F-45F5-9B5E-879D11DC1526_1_105_c.jpg
# data/obj/07012021-20201229_114813.jpg
# data/obj/07012021-20201229_114918.jpg
# data/obj/07012021-20201229_114950.jpg
# data/obj/07012021-20201229_115018.jpg
# data/obj/07012021-20201229_115047.jpg
# data/obj/07012021-20201229_115133.jpg
# data/obj/07012021-20201229_115210.jpg
# data/obj/07012021-20201229_115414.jpg
# ...

# %%
import pandas as pd
  
# read text file into pandas DataFrame
file_test_txt = pd.read_csv("C:\Users\PREDATOR\Documents\Tugas Akhir\Program\test.csv", sep=" ")
  
# display DataFrame
print(file_test_txt)
# Out:
#   File "<ipython-input-59-03c599597024>", line 4
#     file_test_txt = pd.read_csv("C:\Users\PREDATOR\Documents\Tugas Akhir\Program\test.csv", sep=" ")
#                                                                                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# f = open('data/test.txt', 'r')
# file_test = []

# for line in f:
#     file_test.append(repr(line))

# %%
print(file_test)
# Out:
# ["'data/obj/0065-80-1119-39917-q6cg9w_111_display_1_1.jpg\\n'", "'data/obj/014860FA-5BD5-44CE-A1B0-23FA445EC847_1_105_c.jpg\\n'", "'data/obj/01DF2BC4-D359-44F4-8993-314492A6E2FE - Futriana Dwi.jpg\\n'", "'data/obj/02220000256-1833-q6c89h_114_display_1_1.jpg\\n'", "'data/obj/0222002297-36954-q6cp7r_114_display_1_2.jpg\\n'", "'data/obj/023B9E57-FB7A-43C2-9364-7B9971774BD0_1_105_c.jpg\\n'", "'data/obj/034A17BE-2CD9-4F04-A9BF-FAED2DC663BD_1_105_c.jpg\\n'", "'data/obj/0445EA1A-4881-48E6-A186-B53E482FA761_1_105_c.jpg\\n'", "'data/obj/04943877-EA31-45CC-971F-C9449F782421_1_105_c.jpg\\n'", "'data/obj/056E939F-9136-4AB7-9042-20231BEC0F6A_1_105_c.jpg\\n'", "'data/obj/06C798C1-A17F-45F5-9B5E-879D11DC1526_1_105_c.jpg\\n'", "'data/obj/07012021-20201229_114813.jpg\\n'", "'data/obj/07012021-20201229_114918.jpg\\n'", "'data/obj/07012021-20201229_114950.jpg\\n'", "'data/obj/07012021-20201229_115018.jpg\\n'", "'data/obj/07012021-20201229_115047.jpg\\n'", "'data/obj/07012021-20201229_115133.jpg\\n'", "
# ...
