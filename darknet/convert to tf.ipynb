# %%
# !python test.py
# Out:
# saya disini

# %%
# !pip uninstall tensorflow
# import tensorflow as tf
# print(tf. __version__)

# %%
# !python save_model.py --weights ../training/yolov4-tiny-custom_best.weights --output ./checkpoints/yolov4-tiny-416 --input_size 416 --model yolov4 --tiny
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 417, 417, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 208, 208, 32) 864         zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 208, 208, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python detect.py --weights ./checkpoints/yolov4-tiny-416 --size 416 --model yolov4 --image ./data/test.jpg --tiny
# Out:
# 2023-03-15 15:04:54.631244: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudart64_110.dll
# 2023-03-15 15:04:57.670865: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2023-03-15 15:04:58.642932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1650 computeCapability: 7.5
# coreClock: 1.56GHz coreCount: 16 deviceMemorySize: 4.00GiB deviceMemoryBandwidth: 119.24GiB/s
# 2023-03-15 15:04:58.643191: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudart64_110.dll
# 2023-03-15 15:04:58.659634: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cublas64_11.dll
# ...

# %%
# !cd C:/Users/PREDATOR/Downloads/Compressed/tensorflow-yolov4-tflite-master/tensorflow-yolov4-tflite-master/

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 9EB4-2514
#
#  Directory of C:\Users\PREDATOR\Downloads\cobaData\yolov4-tiny\darknet
#
# 15/03/2023  15:11    <DIR>          .
# 15/03/2023  09:23    <DIR>          ..
# 09/03/2023  08:02    <DIR>          .circleci
# 09/03/2023  08:02    <DIR>          .github
# 03/03/2023  09:24               699 .gitignore
# 15/03/2023  12:57    <DIR>          .ipynb_checkpoints
# 09/03/2023  08:02    <DIR>          3rdparty
# 09/03/2023  08:31            29.061 ALL_BUILD.vcxproj
# 09/03/2023  08:31               323 ALL_BUILD.vcxproj.filters
# 09/03/2023  08:31               168 ALL_BUILD.vcxproj.user
# 09/03/2023  08:02    <DIR>          build
# 03/03/2023  09:24            39.838 build.ps1
# 15/03/2023  09:22    <DIR>          cfg
# 15/03/2023  12:17            85.628 chart.png
# 15/03/2023  12:17            85.628 chart_yolov4-tiny-custom.png
# 15/03/2023  14:55    <DIR>          checkpoints
# 09/03/2023  08:02    <DIR>          cmake
# ...
